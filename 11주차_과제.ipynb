# %% [markdown]
# <a href="https://colab.research.google.com/github/bjpark-forest/2023-1-Intro-DataScience/blob/main/11%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 7장

# %%
# 맷플롯 한글 폰트 깨짐 현상에 대한 해결 방법
# 1) 한글 폰트 설치
# 2) 설치 후 런타임 다시 시작
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# 3) 한글 폰트 읽어오기

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_path, size=10).get_name()

plt.rc('font', family=font_name)

# %%
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###문제3
# - '7장_연습1.xlsx' 읽어와 각 속성의 결측치 확인하는 빈칸 작성

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel('7장_연습1.xlsx')
# 빈칸
# Out:
# id                  0
# name                0
# age                 0
# continent           0
# contract_until      0
# position            0
# prefer_foot         0
# reputation          0
# stat_overall        0
# stat_potential      0
# stat_skill_moves    0
# value               0
# dtype: int64

# %% [markdown]
# ###문제4
# - '7장_연습1.xlsx' 읽어와 나이('age')에 따른 value 산점도 확인 후 이상치 제거하는 빈칸 작성

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('7장_연습1.xlsx')
plt.figure(figsize=(10,7))
plt.scatter(x = df['age'], y = df['value'])
plt.grid()
plt.show

# %%
# 빈칸
plt.figure(figsize=(10,5))
plt.scatter(x = df['age'], y = df['value'])
plt.grid()
plt.show

# %% [markdown]
# ###문제5
# - '7장_연습문제2.csv'의 타이타닉호 탑승자 정보를 이용하여 다음의 조건을 차례대로 수행하는 빈칸 작성
#
#  ![111.png](data:image/png;base64,...)

# %% [markdown]
# #### 1) 데이터 결측값 확인하는 빈칸 작성

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('7장_연습문제2.csv')
# 빈칸
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### 2) Age 결측값을 평균값으로 대체하는 빈칸 작성

# %%
# 빈칸
# 빈칸
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### 3) 객실등급(pclass)별 생존율의 평균을 시각화하는 빈칸 작성

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 빈칸
plt.xticks(range(1, 4))
plt.show()

# %% [markdown]
# #### 4) 성별에 따른 생존율을 시각화하는 빈칸 작성

# %%
value_counts = df['Survived'].value_counts()
# 빈칸
plt.ylabel('Survived')
plt.show()

# %% [markdown]
# #### 5) 승객 연령대별 분포를 시각화하는 빈칸 작성

# %%
# 빈칸
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 6) 연령대별 생존율을 시각화하는 빈칸 작성

# %%
# 빈칸
# 빈칸
plt.xlabel('Age')
plt.show()

# %% [markdown]
# #### 7) 각 속성을 상관관계로 시각화하는 빈칸 작성

# %%
# 빈칸
plt.show()
