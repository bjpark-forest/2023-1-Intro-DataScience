# %% [markdown]
# <a href="https://colab.research.google.com/github/bjpark-forest/2023-1-Intro-DataScience/blob/main/3%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2장 파이썬 핵심 문법

# %% [markdown]
# ## 2.10 파이썬 핵심 문법 연습 문제

# %% [markdown]
# ###문제1

# %%
# Out:
# 학교: 한국대
# 학과: 컴공
# 이름: 이순신
# 연락처: 010-1234-5678

# %% [markdown]
# ###문제2

# %%
# Out:
# 총매출 :  145000
# 순이익 :  45000

# %% [markdown]
# ###문제3

# %%
# Out:
# 이름 입력: 이순신
# 출생년도 입력: 2002
# 이순신님의 한국 나이는 18살

# %% [markdown]
# ###문제4

# %%
spot = ['을지로', '가로수길', '홍대', '대학로']
# Out:
# ['홍대', '대학로']

# %% [markdown]
# ###문제5

# %%
person = {100:'이순신', 200:'강감찬', 300:'김유신'}
# Out:
# [100, 200, 300]

# %%
# Out:
# ['이순신', '강감찬', '김유신']

# %%
# Out:
# [(100, '이순신'), (200, '강감찬'), (300, '김유신')]

# %%
# Out:
# '강감찬'

# %%
# Out:
# {200: '강감찬', 300: '김유신'}

# %% [markdown]
# ###문제6

# %%
addr={}

addr['이순신']='010-1111-1234'
addr['강감찬']='010-2222-1234'
addr['김유신']='010-3333-1234'
addr['안중근']='010-4444-1234'
addr['유관순']='010-5555-1234'
# Out:
# ['이순신', '강감찬', '김유신', '안중근', '유관순']
#
# 찾는 이름 : 김유신
# 010-3333-1234

# %% [markdown]
# ###문제7

# %%
clubA = {'김유신', '이순신', '강감찬'}
clubB = {'이순신', '계백', '최영'}

# %%
# Out:
# {'강감찬', '최영', '김유신', '계백', '이순신'}

# %%
# Out:
# {'이순신'}

# %%
# Out:
# {'강감찬', '김유신'}

# %%
# Out:
# {'계백', '최영'}

# %%
# Out:
# {'강감찬', '김유신', '이순신', '이황'}

# %%
# Out:
# {'이순신', '최영'}

# %%
food=['사과','바나나','초콜렛','디저트','멜론','샤인머스켓']
# Out:
# ['바나나', '초콜렛', '디저트']
